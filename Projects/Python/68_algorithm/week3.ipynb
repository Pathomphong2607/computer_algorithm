# %%
a = 1
b = 2
print("sum : ", a+b)
print("minus : ", a-b)
print("multiply : ", a*b) 
print("div : " , a/b)
print("? : " , a%b)
# Out:
# sum :  3
# minus :  -1
# multiply :  2
# div :  0.5
# ? :  1

# %%
a = 3
b = 2
if( a>b ):
    print("A มากกว่า B")
elif(a==b):
    print("A เท่ากันกับ B")
else:
    print("A น้อยกว่า B")
# Out:
# A มากกว่า B

# %%
score = input("score is :")
score = int(score)
if(score >=80):
        print("A")
elif(score >=70):
        print("B+")
elif(score >=70):
        print("B")
elif(score >=65):
        print("C+")
elif(score >=60):
        print("C")
elif(score >=55):
        print("D+")
elif(score >=50):
        print("D")
else:
        print("F")
# Out:
# B+

# %%
fname = input("fname is :")
lname = input("lname is :")
score = input("score is :")

score = int(score)
if(score >=80):
        print(fname,lname,"A")
elif(score >=70):
        print(fname,lname,"B+")
elif(score >=70):
        print(fname,lname,"B")
elif(score >=65):
        print(fname,lname,"C+")
elif(score >=60):
        print(fname,lname,"C")
elif(score >=55):
        print(fname,lname,"D+")
elif(score >=50):
        print(fname,lname,"D")
else:
        print(fname,lname,"F")
# Out:
# pp pp B+
